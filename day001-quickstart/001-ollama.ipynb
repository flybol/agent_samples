# %%
# 调用大模型api服务
from langchain.chat_models import init_chat_model

model = init_chat_model(model="deepseek-chat")

for chunck in model.stream("写一首冬日风景唐诗"):
    print(chunck.content, end="", flush=True)
# Out:
# 《冬日山行》
# 千峰覆雪寂无声，万径封冰少客行。
# 松枝凝玉寒光冽，岩壁垂银晓色明。
# 野渡孤舟横冷岸，荒村犬吠伴风鸣。
# 何当共赏琼瑶境，且待春来百鸟嘤。
#
# 注：本诗通过“千峰覆雪”、“万径封冰”等意象勾勒出冬日山野的静谧肃杀，颔联以松枝凝玉、岩壁垂银的工笔细描强化视觉寒意。后两联转以动破静，孤舟荒村间犬吠风鸣，更显天地苍茫。尾联寄望春归，在传统咏冬诗中翻出希冀之笔，暗合唐人“寒极春生”的宇宙观。

# %% [markdown]
# uv add langchain-community
# uv add langchain-deepseek
# uv add langchain-ollama
#
# #模型下载
# 聊天模型：deepseek-r1:1.5b
# 嵌入模型：nomic-embed-text
#
# #向量数据库
# uv add chromadb langchain-chroma

# %%
# 调用本地大模型服务
from langchain.ollama import Llama
